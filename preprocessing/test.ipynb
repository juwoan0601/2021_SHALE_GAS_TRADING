# %%
import pandas as pd
import os

print(os.getcwd())
df = pd.read_csv("D:/POSTECH/대외활동/2021 제1회 데이터사이언스경진대회/data/trainSet.csv", index_col=0)
df.tail()
# Out:
# d:\POSTECH\대외활동\2021 제1회 데이터사이언스경진대회\2021_SHALE_GAS_TRADING\preprocessing
#      CPA Pretty Well ID  Reference (KB) Elev. (ft)  Ground Elevation (ft)  \
# No
# 708                 286                       3048                   3027
# 716                 287                       3081                   3057
# 718                 288                       3083                   3057
# 720                 289                       3036                   3019
# 722                 290                       3083                   3061
#
#      MD (All Wells) (ft)  TVD (ft)  Bot-Hole direction (N/S)/(E/W)  \
# No
# 708                19462     10351                        0.061657
# 716                20932     10036                        0.839577
# 718                20276     10112                        0.342466
# 720                20728     10218                        1.203390
# 722                20364     10130                        0.963504
#
# ...

# %%
df.iloc[0]["TVD (ft)"]
# Out:
# 10746
